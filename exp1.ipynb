# %%
# MDP Representation using Python

print("Name: Suresh S")
print("Register Number: 212223040215")

states = {
    "S1": "Pharmacy",
    "S2": "Main Corridor",
    "S3": "Reception Area",
    "S4": "Emergency Corridor",
    "S5": "Patient Room Corridor",
    "S6": "Patient Room"
}

actions = {
    "S1": ["Forward", "Right"],
    "S2": ["Forward", "Left", "Right"],
    "S3": ["Forward", "Right"],
    "S4": ["Forward", "Left"],
    "S5": ["Forward", "Left", "Right"],
    "S6": ["Stop"]
}

transitions = {
    ("S1", "Forward"): {"S2": 0.9, "S3": 0.1},
    ("S2", "Forward"): {"S5": 0.9, "S4": 0.1},
    ("S3", "Forward"): {"S4": 0.9, "S2": 0.1},
    ("S4", "Forward"): {"S5": 0.9, "S4": 0.1},
    ("S5", "Forward"): {"S6": 0.9, "S5": 0.1}
}

rewards = {
    ("S1", "Forward", "S2"): -1,
    ("S2", "Forward", "S5"): -1,
    ("S3", "Forward", "S4"): -1,
    ("S4", "Forward", "S5"): -1,
    ("S5", "Forward", "S6"): 100
}

gamma = 0.9

print("States:", states)
print("Actions:", actions)
print("Transition Probabilities:", transitions)
print("Rewards:", rewards)
print("Discount Factor:", gamma)
# Out:
# Name: Suresh S
# Register Number: 212223040215
# States: {'S1': 'Pharmacy', 'S2': 'Main Corridor', 'S3': 'Reception Area', 'S4': 'Emergency Corridor', 'S5': 'Patient Room Corridor', 'S6': 'Patient Room'}
# Actions: {'S1': ['Forward', 'Right'], 'S2': ['Forward', 'Left', 'Right'], 'S3': ['Forward', 'Right'], 'S4': ['Forward', 'Left'], 'S5': ['Forward', 'Left', 'Right'], 'S6': ['Stop']}
# Transition Probabilities: {('S1', 'Forward'): {'S2': 0.9, 'S3': 0.1}, ('S2', 'Forward'): {'S5': 0.9, 'S4': 0.1}, ('S3', 'Forward'): {'S4': 0.9, 'S2': 0.1}, ('S4', 'Forward'): {'S5': 0.9, 'S4': 0.1}, ('S5', 'Forward'): {'S6': 0.9, 'S5': 0.1}}
# Rewards: {('S1', 'Forward', 'S2'): -1, ('S2', 'Forward', 'S5'): -1, ('S3', 'Forward', 'S4'): -1, ('S4', 'Forward', 'S5'): -1, ('S5', 'Forward', 'S6'): 100}
# Discount Factor: 0.9
